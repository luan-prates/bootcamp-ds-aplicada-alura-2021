# %% [markdown]
# <a href="https://colab.research.google.com/github/luan-prates/bootcamp-ds-aplicada-alura-2021/blob/main/Analise_dos_dados_SIH_Datasus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Analise dos dados SIH - Datasus

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/alura-cursos/agendamento-hospitalar/main/dados/A151346189_28_143_208.csv',encoding='ISO-8859-1' , sep=';', 
                 skiprows = 3, skipfooter=12, thousands='.',decimal=',', engine='python')

# %%
df.head()
# Out:
#   Unidade da Federação     2008/Jan  ...     2020/Ago         Total
# 0          11 Rondônia   1388528.39  ...  10285455.78  9.291297e+08
# 1              12 Acre    902416.00  ...            -  4.206680e+08
# 2          13 Amazonas   4735529.42  ...  14726443.67  1.771655e+09
# 3           14 Roraima    657889.53  ...   2826486.18  3.050109e+08
# 4              15 Pará  18864744.11  ...  39911193.02  4.437116e+09
#
# [5 rows x 154 columns]

# %%
df.tail()
# Out:
#      Unidade da Federação     2008/Jan  ...      2020/Ago         Total
# 22   43 Rio Grande do Sul  30931325.46  ...  101374341.51  1.195865e+10
# 23  50 Mato Grosso do Sul   5377392.11  ...   19241624.02  2.172158e+09
# 24         51 Mato Grosso   4795299.01  ...   17790649.87  2.036924e+09
# 25               52 Goiás  15310637.29  ...   43984702.05  4.657350e+09
# 26    53 Distrito Federal   4745919.19  ...   26526196.39  2.429933e+09
#
# [5 rows x 154 columns]

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
df['2008/Ago']
# Out:
# 0      3231494.61
# 1      2089107.14
# 2      9352532.70
# 3       894271.18
# 4     23341218.03
# 5      1475551.38
# 6      5413710.38
# 7     15195312.89
# 8     10549176.40
# 9     27851438.72
# 10    10640817.47
# 11    12872578.37
# 12    35457038.66
# 13     9373432.00
# 14     5238398.50
# 15    46931248.28
# 16    84722528.10
# 17    12588595.77
# 18    50912706.60
# 19   184854516.35
# 20    56982774.90
# 21    31250854.33
# 22    56113054.70
# 23     9671553.45
# 24     9243148.81
# 25    20650730.67
# 26    13710857.89
# Name: 2008/Ago, dtype: float64

# %%
df['2020/Ago'].plot()

# %%
df.plot(x='Unidade da Federação',y='2008/Ago', kind='bar', rot=90, figsize=(10,6))

# %%
df['2020/Ago'] = df['2020/Ago'].astype(float)

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

ano_mes = '2020/Ago'

#todo - criar uma função para converter automaticamente o tipo de dado
df['2020/Ago'] = df['2020/Ago'].astype(float)

ax = df.plot(x='Unidade da Federação',y=ano_mes , kind='bar', rot=90, figsize=(10,6))

ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.title(f"Valor da Produção Hospitalar por estado em {ano_mes}")

plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
df.loc[(df['2020/Ago'] == '-'),'2020/Ago']=0

# %%
df['2020/Ago']
# Out:
# 0      10285455.78
# 1                0
# 2      14726443.67
# 3       2826486.18
# 4      39911193.02
# 5       2942273.94
# 6       8240261.38
# 7      28587541.78
# 8      23210624.20
# 9      59808605.59
# 10     24929930.72
# 11     22130016.81
# 12     75704177.72
# 13     19754741.78
# 14     11014180.89
# 15     80793117.08
# 16    168024412.95
# 17     32188873.88
# 18     95274486.35
# 19    346512263.17
# 20    129375911.54
# 21     63972379.36
# 22    101374341.51
# 23     19241624.02
# 24     17790649.87
# 25     43984702.05
# 26     26526196.39
# Name: 2020/Ago, dtype: object
