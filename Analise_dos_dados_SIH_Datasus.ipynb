# %% [markdown]
# <a href="https://colab.research.google.com/github/luan-prates/bootcamp-ds-aplicada-alura-2021/blob/main/Analise_dos_dados_SIH_Datasus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analise dos dados SIH - Datasus
#
# ## Aquisição e Leitura de dados reais
#
# ## Primeiras visualizações de dados
#
# ## Manipulação de dados
#
# ## Análise gráfica e criação da hipotese
#
# ## Manipulação e Interpretação de gráficos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
df = pd.read_csv('https://raw.githubusercontent.com/alura-cursos/agendamento-hospitalar/main/dados/A151346189_28_143_208.csv',encoding='ISO-8859-1' , sep=';', 
                 skiprows = 3, skipfooter=12, thousands='.',decimal=',', engine='python')

# %%
df.head()
# Out:
#   Unidade da Federação    2008/Jan  ...     2020/Ago         Total
# 0          11 Rondônia  1388528.39  ...  10285455.78  929129659.72
# 1              12 Acre   902416.00  ...            -  420668039.63
# 2          13 Amazonas  4735529.42  ...  14726443.67 1771654871.23
# 3           14 Roraima   657889.53  ...   2826486.18  305010883.18
# 4              15 Pará 18864744.11  ...  39911193.02 4437115730.71
#
# [5 rows x 154 columns]

# %%
df.tail()
# Out:
#      Unidade da Federação    2008/Jan  ...      2020/Ago          Total
# 22   43 Rio Grande do Sul 30931325.46  ...  101374341.51 11958647088.33
# 23  50 Mato Grosso do Sul  5377392.11  ...   19241624.02  2172157981.36
# 24         51 Mato Grosso  4795299.01  ...   17790649.87  2036923784.59
# 25               52 Goiás 15310637.29  ...   43984702.05  4657350310.70
# 26    53 Distrito Federal  4745919.19  ...   26526196.39  2429933198.76
#
# [5 rows x 154 columns]

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
df.plot(x='Unidade da Federação',y='2008/Ago', kind='bar', rot=90, figsize=(10,6))

# %%
ano_mes = input("Entre com o Ano/mes: ") or '2020/Ago'
df[ano_mes] = pd.to_numeric(df[ano_mes], errors='coerce')

ax = df.plot(x='Unidade da Federação',y=ano_mes , kind='bar', rot=90, figsize=(10,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title(f"Valor da Produção Hospitalar por estado em {ano_mes}")
plt.show
# Out:
# Entre com o Ano/mes:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Primeiras visualizações de dados

# %%
df_2 = pd.read_csv('https://raw.githubusercontent.com/alura-cursos/agendamento-hospitalar/main/dados/A160324189_28_143_208.csv', encoding='ISO-8859-1',
                   sep=';', skiprows=3, skipfooter=12, thousands='.', decimal=',', engine='python')

# %%
df_2.head()
# Out:
#   Unidade da Federação 1992/Mar 1992/Abr  ...    2020/Jul     2020/Ago         Total
# 0          11 Rondônia        -        -  ...  7407388.24   3556381.57  929129659.72
# 1              12 Acre        -        -  ...  1163813.08            -  420668039.63
# 2          13 Amazonas        -        -  ... 13358514.02   4726485.73 1771654871.23
# 3           14 Roraima        -        -  ...  2739498.41   1524478.04  305010883.18
# 4              15 Pará        -        -  ... 27618727.51  11559714.54 4437115730.71
#
# [5 rows x 280 columns]

# %%
df_2[['2008/Ago', '2008/Set']].head()
# Out:
#      2008/Ago    2008/Set
# 0  2938286.29  2843930.91
# 1  1886871.84  2084884.80
# 2  8331763.97  8148089.92
# 3  1045291.11  1003740.89
# 4 23259148.28 23667690.01

# %%
df_2.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Abr     40005678.92
# 2020/Mai     46769027.82
# 2020/Jun     45367349.74
# 2020/Jul     40717083.95
# Total      5993724452.01
# Length: 157, dtype: float64

# %% [markdown]
# Repare que algumas colunas não aprecem, isso contece pq essas colunas tem valores faltates, então podemos usar isso para pegar apenas as colunas que tem todos os valores.

# %%
colunas_completas = df_2.mean().index.tolist()
colunas_completas.insert(0, 'Unidade da Federação')
colunas_completas
# Out:
# ['Unidade da Federação',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
# ...

# %%
dff_2 = df_2[colunas_completas]
dff_2.head()
# Out:
#   Unidade da Federação  2007/Ago  ...    2020/Jul         Total
# 0          11 Rondônia   4209.37  ...  7407388.24  929129659.72
# 1              12 Acre  10470.07  ...  1163813.08  420668039.63
# 2          13 Amazonas  35752.72  ... 13358514.02 1771654871.23
# 3           14 Roraima   4785.91  ...  2739498.41  305010883.18
# 4              15 Pará 181159.29  ... 27618727.51 4437115730.71
#
# [5 rows x 158 columns]

# %%
dff_2.set_index('Unidade da Federação', inplace=True)

# %%
dff_2.head()
# Out:
#                       2007/Ago  2007/Set  ...    2020/Jul         Total
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  7407388.24  929129659.72
# 12 Acre               10470.07  14001.71  ...  1163813.08  420668039.63
# 13 Amazonas           35752.72  45570.64  ... 13358514.02 1771654871.23
# 14 Roraima             4785.91  11858.63  ...  2739498.41  305010883.18
# 15 Pará              181159.29 433414.74  ... 27618727.51 4437115730.71
#
# [5 rows x 157 columns]

# %%
dff_2['2007/Ago'].head()
# Out:
# Unidade da Federação
# 11 Rondônia     4209.37
# 12 Acre        10470.07
# 13 Amazonas    35752.72
# 14 Roraima      4785.91
# 15 Pará       181159.29
# Name: 2007/Ago, dtype: float64

# %%
dff_2.loc["23 Ceará"]
# Out:
# 2007/Ago       357904.65
# 2007/Set       572356.18
# 2007/Out      1865065.71
# 2007/Nov      5131814.39
# 2007/Dez     10798042.86
#                 ...
# 2020/Abr     43468816.62
# 2020/Mai     54200339.48
# 2020/Jun     42146555.81
# 2020/Jul     30809221.22
# Total      6197357245.98
# Name: 23 Ceará, Length: 157, dtype: float64

# %%
#dff_2.plot(figsize=(12,6))

# %%
dff_2.T.head()
# Out:
# Unidade da Federação  11 Rondônia   12 Acre  ...   52 Goiás  53 Distrito Federal
# 2007/Ago                  4209.37  10470.07  ...  179395.82            191951.47
# 2007/Set                 16397.03  14001.71  ...  418053.58            769966.25
# 2007/Out                133645.19  86200.85  ... 1198730.25           2165619.56
# 2007/Nov                346912.84 301323.68  ... 2712117.54           3813256.48
# 2007/Dez                711758.31 769612.36  ... 9293914.78           7121965.42
#
# [5 rows x 27 columns]

# %%
dff_2.T.tail()
# Out:
# Unidade da Federação  11 Rondônia  ...  53 Distrito Federal
# 2020/Abr               7423678.64  ...          18123899.78
# 2020/Mai               8581195.13  ...          21437430.22
# 2020/Jun               9193593.76  ...          23479773.03
# 2020/Jul               7407388.24  ...          22233542.26
# Total                929129659.72  ...        2429933198.76
#
# [5 rows x 27 columns]

# %%
dff_2.drop("Total", axis=1, inplace=True)
dff_2.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                       2007/Ago  2007/Set  ...    2020/Jun    2020/Jul
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  9193593.76  7407388.24
# 12 Acre               10470.07  14001.71  ...  2199920.70  1163813.08
# 13 Amazonas           35752.72  45570.64  ... 17509334.66 13358514.02
# 14 Roraima             4785.91  11858.63  ...  3216466.51  2739498.41
# 15 Pará              181159.29 433414.74  ... 35396030.78 27618727.51
#
# [5 rows x 156 columns]

# %%
dff_2.T.plot(figsize=(10,6)).legend(bbox_to_anchor=(1, 1.1), frameon=False)

# %%
dff_2.T.columns[0:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
dff_2.index[0:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
dff_2[:5].T.plot(figsize=(10,6))

# %%
np.random.seed(1313)
dff_2.sample(n=5).T.plot(figsize=(10,6))

# %%
dff_2['Total'] = dff_2.sum(axis=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dff_2.head()
# Out:
#                       2007/Ago  2007/Set  ...    2020/Jul         Total
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  7407388.24  925572673.82
# 12 Acre               10470.07  14001.71  ...  1163813.08  420666755.81
# 13 Amazonas           35752.72  45570.64  ... 13358514.02 1766925554.09
# 14 Roraima             4785.91  11858.63  ...  2739498.41  303485991.45
# 15 Pará              181159.29 433414.74  ... 27618727.51 4425537480.57
#
# [5 rows x 157 columns]

# %%
estados = dff_2.index.to_list()

# %%
estados_tratados = []
for estado in estados:
  estados_tratados.append(estado[3:])
  print(estado[3:])
# Out:
# Rondônia
# Acre
# Amazonas
# Roraima
# Pará
# Amapá
# Tocantins
# Maranhão
# Piauí
# Ceará
# Rio Grande do Norte
# Paraíba
# Pernambuco
# Alagoas
# Sergipe
# Bahia
# Minas Gerais
# Espírito Santo
# Rio de Janeiro
# São Paulo
# Paraná
# Santa Catarina
# Rio Grande do Sul
# Mato Grosso do Sul
# Mato Grosso
# Goiás
# Distrito Federal

# %%
dff_2['Estado'] = estados_tratados
dff_2['Estado']
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# Unidade da Federação
# 11 Rondônia                          Rondônia
# 12 Acre                                  Acre
# 13 Amazonas                          Amazonas
# 14 Roraima                            Roraima
# 15 Pará                                  Pará
# 16 Amapá                                Amapá
# 17 Tocantins                        Tocantins
# 21 Maranhão                          Maranhão
# 22 Piauí                                Piauí
# 23 Ceará                                Ceará
# 24 Rio Grande do Norte    Rio Grande do Norte
# ...

# %%
estados_regoes = {'Amazonas':'Norte','Roraima':'Norte','Amapá':'Norte','Pará':'Norte','Tocantins':'Norte','Rondônia':'Norte','Acre':'Norte','Maranhão':'Nordeste',
                  'Piauí':'Nordeste','Ceará':'Nordeste','Rio Grande do Norte':'Nordeste','Pernambuco':'Nordeste','Paraíba':'Nordeste','Sergipe':'Nordeste',
                  'Alagoas':'Nordeste','Bahia':'Nordeste','Mato Grosso':'Centro-Oeste','Mato Grosso do Sul':'Centro-Oeste','Goiás':'Centro-Oeste',
                  'Distrito Federal':'Centro-Oeste','São Paulo':'Sudeste','Rio de Janeiro':'Sudeste','Espírito Santo':'Sudeste','Minas Gerais':'Sudeste',
                  'Paraná':'Sul','Rio Grande do Sul':'Sul','Santa Catarina':'Sul'}

# %%
dff_2['Regiao'] = dff_2['Estado'].map(estados_regoes)
dff_2['Regiao']
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# Unidade da Federação
# 11 Rondônia                      Norte
# 12 Acre                          Norte
# 13 Amazonas                      Norte
# 14 Roraima                       Norte
# 15 Pará                          Norte
# 16 Amapá                         Norte
# 17 Tocantins                     Norte
# 21 Maranhão                   Nordeste
# 22 Piauí                      Nordeste
# 23 Ceará                      Nordeste
# 24 Rio Grande do Norte        Nordeste
# 25 Paraíba                    Nordeste
# 26 Pernambuco                 Nordeste
# ...

# %%
dff_3 = dff_2
dff_3.set_index(['Regiao', 'Estado'], inplace=True)

# %%
dff_3.tail()
# Out:
#                                   2007/Ago  ...          Total
# Regiao       Estado                         ...
# Sul          Rio Grande do Sul  1049252.33  ... 11930181093.98
# Centro-Oeste Mato Grosso do Sul  199556.12  ...  2168089038.24
#              Mato Grosso          63562.50  ...  2030739826.14
#              Goiás               179395.82  ...  4637039055.60
#              Distrito Federal    191951.47  ...  2417774340.23
#
# [5 rows x 157 columns]

# %%
dff_3.loc['Nordeste']
# Out:
#                      2007/Ago   2007/Set  ...    2020/Jul         Total
# Estado                                    ...
# Maranhão            385330.18 1018352.93  ... 24374205.15 3621885105.60
# Piauí               220788.25  353468.67  ... 18019214.49 2122676207.29
# Ceará               357904.65  572356.18  ... 30809221.22 6182786402.04
# Rio Grande do Norte 134605.36  272088.08  ... 19593057.45 2469235766.39
# Paraíba              97352.78  368130.43  ... 15491469.06 2461941658.63
# Pernambuco          400640.85 1088340.42  ... 62325444.34 8013135105.77
# Alagoas             104243.75  174024.90  ... 13087850.40 2097903424.04
# Sergipe              27453.63   78565.19  ...  3312766.32 1128585323.09
# Bahia               135146.36  448349.75  ... 58898100.40 9167733691.21
#
# [9 rows x 157 columns]

# %%
dff_4 = dff_3
dff_4.drop("Total", axis=1, inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
 dff_4.sum(level=0).T.plot(figsize=(10,6))
